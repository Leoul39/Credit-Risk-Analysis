# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scorecardpy as sc
from monotonic_binning.monotonic_woe_binning import Binning
import os
os.chdir('..')
from scripts.utils import features

# %%
df=pd.read_csv('C:/Users/abenet/Desktop/data/Week 6/Technical Content/data/data.csv')
df
# Out:
#               TransactionId         BatchId       AccountId       SubscriptionId       CustomerId CurrencyCode  CountryCode    ProviderId     ProductId     ProductCategory    ChannelId   Amount  Value  TransactionStartTime  PricingStrategy  FraudResult
# 0       TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10             airtime  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z                2            0
# 1       TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z                2            0
# ...

# %% [markdown]
# ### Feature Engineering

# %%
df=features(df)
df
# Out:
#               TransactionId         BatchId       AccountId       SubscriptionId       CustomerId CurrencyCode  CountryCode    ProviderId     ProductId     ProductCategory    ChannelId   Amount  Value      TransactionStartTime  PricingStrategy  FraudResult  Hour  Day  Month  Year  TotalTransactionAmount  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10             airtime  ChannelId_3   1000.0   1000 2018-11-15 02:18:49+00:00                2            0     2   15     11  2018                156884.0
# 1       TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6  financial_services  ChannelId_2    -20.0     20 2018-11-15 02:19:08+00:00                2            0     2   15     11  2018             -27750277.5
# ...

# %%
train, test = sc.split_df(df, 'FraudResult', ratio = 0.7, seed = 999).values()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95662 entries, 0 to 95661
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TransactionId             95662 non-null  object
#  1   BatchId                   95662 non-null  object
#  2   AccountId                 95662 non-null  object
#  3   SubscriptionId            95662 non-null  object
#  4   CustomerId                95662 non-null  object
#  5   CurrencyCode              95662 non-null  object
#  6   CountryCode               95662 non-null  int64
#  7   ProviderId                95662 non-null  object
#  8   ProductId                 95662 non-null  object
#  9   ProductCategory           95662 non-null  object
#  10  ChannelId                 95662 non-null  object
#  11  Amount                    95662 non-null  float64
#  12  Value                     95662 non-null  int64
# ...

# %%
cat=list(df.select_dtypes(include=['object','datetime64[ns, UTC]']))
var = train.drop(cat, axis = 1).columns
y_var = train['FraudResult']


bin_object = Binning('FraudResult', n_threshold = 50, y_threshold = 10, p_threshold = 0.35, sign=False)
global breaks
breaks = {}
for i in var:
    np.Inf=np.inf
    bin_object.fit(train[['FraudResult', i]])
    breaks[i] = (bin_object.bins[1:-1].tolist())
train[['FraudResult','']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[30], line 11
#       9 for i in var:
#      10     np.Inf=np.inf
# ---> 11     bin_object.fit(train[['FraudResult', i]])
#      12     breaks[i] = (bin_object.bins[1:-1].tolist())
#
# File c:\Users\abenet\Desktop\Trial\Credit-Risk-Analysis\.venv\Lib\site-packages\monotonic_binning\monotonic_woe_binning.py:192, in Binning.fit(self, dataset)
#     190 def fit(self, dataset):
#     191     self.dataset = dataset
# --> 192     self.column = self.dataset.columns[self.dataset.columns != self.y][0]
#     194     self.generate_summary()
#     195     self.combine_bins()
#
# File c:\Users\abenet\Desktop\Trial\Credit-Risk-Analysis\.venv\Lib\site-packages\pandas\core\indexes\base.py:5389, in Index.__getitem__(self, key)
#    5386 if is_integer(key) or is_float(key):
# ...

# %%
woe_num(var, 'FraudResult')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 woe_num(var, 'FraudResult')
#
# Cell In[26], line 11, in woe_num(x, y)
#       8 breaks = {}
#      10 for i in x:
# ---> 11     bin_object.fit(train[[y, i]])
#      13     # Ensure that bins are not empty and have more than two elements
#      14     if bin_object.bins is not None and len(bin_object.bins) > 2:
#
# File c:\Users\abenet\Desktop\Trial\Credit-Risk-Analysis\.venv\Lib\site-packages\monotonic_binning\monotonic_woe_binning.py:192, in Binning.fit(self, dataset)
#     190 def fit(self, dataset):
#     191     self.dataset = dataset
# --> 192     self.column = self.dataset.columns[self.dataset.columns != self.y][0]
#     194     self.generate_summary()
#     195     self.combine_bins()
#
# ...
